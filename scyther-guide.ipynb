# %% [markdown]
# # installed scyther

# %% [markdown]
# ```bash
# $ ./../scyther-linux-v1.3.0/Scyther/scyther-linux --dot-output --output=attack.dot ./../scyther-linux-v1.3.0/Protocols/Demo/ns3.spdl
# $ dot -Tsvg attack.dot -o attack.svg
# ```

# %% [markdown]
# <img src="./images/attack.svg" width="width_length" height="height_length" alt="alt text">
